# %% [markdown]
# <a href="https://colab.research.google.com/github/uniqueraj/Python-with-RB/blob/main/Weather_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:- Rajendra Budha**
#
# 💕💖
#
# > " Practice Makes Perfect Man "

# %% [markdown]
# **INSTALL**

# %%
# Installing
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %% [markdown]
# **IMPORT MODULES**

# %%
# Importing Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **IMPORTING DATAS**

# %%
# Importing Data if you have data
df=pd.read_csv('https://raw.githubusercontent.com/jsdhami/Python-For-Research/main/Data/nepal-earthquake-severity-index-latest.csv')

df = pd.DataFrame({'District':df['DISTRICT'], 'Housing':df['Housing'], 'Poverty':df['Poverty'], 'Vulnerability':df['Vulnerability']})
df.head()
print(len(df))
# Out:
# 3986

# %%
df = df.tail(8)
df.head()
print(df.to_string())
# Out:
#          District  Housing  Poverty  Vulnerability
# 3978       Bajura     8.08     8.80           8.44
# 3979      Bajhang     8.74     7.05           7.89
# 3980       Achham     8.45     9.21           8.83
# 3981         Doti     8.77     8.26           8.52
# 3982      Bardiya     4.64     4.82           4.73
# 3983  Nawalparasi     5.61     3.51           4.56
# 3984    Rupandehi     7.81     2.95           5.38
# 3985          NaN      NaN      NaN            NaN

# %% [markdown]
# **CREAT DATA FRAME**

# %%
# Create Data
x=df['District'].astype(str)
y=df['Housing']
z=df['Poverty']
v=df['Vulnerability']

# %% [markdown]
# **A. LINE PLOTING**

# %%
# Line Ploting For All
# Creating Fig
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.plot(x, y, 'o-', label='Housing',  color='blue')
ax.plot(x, z, 'o--', label='Poverty', color='black')
ax.plot(x, v, 'o-', label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index',
             color='green', fontsize=12, weight=20)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()

# %%
# Line Ploting For 'Housing'
# Creating Fig of Graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.plot(x, y, 'o--', label='Housing', color='blue')

#labeling of graph
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquike Housing Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()

# %%
# Line Graph Ploting For 'Poverty'
# Creating Graph Figure Model
fig, ax= plt.subplots()
fig.set_size_inches(15, 5)

ax.plot(x, z, 'o--', label='Poverty', color='black')

#label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()

# %%
# line Graph Ploting FOr 'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.plot(x, v, 'o--', label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=14)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()

# %% [markdown]
# **B. STACK GRAOH PLOTING**

# %%
# Stack Ploting For 'Housing, Poverty, and Vulnerability'
# Creating Graph Figure Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stackplot(x, y, z, v,  labels=['Housing', 'Poverty', 'Vulnerability'], colors=['blue', 'black', 'red'])

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(0, 30)

ax.legend()

plt.grid(True)

plt.show()

# %%
# Stack Graph Ploting For 'Housing'
# Create Graph Model Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stackplot(x, y, labels=['Housing'], colors=['blue'])

# Label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(0, 12)

ax.legend()

plt.grid(True)

plt.show()

# %%
# Satack ploting fo Poverty
# Create Graph Model Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stackplot(x, z, labels=['Poverty'], color=['black'])

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(0, 12)

ax.legend()

plt.grid(True)

plt.show()

# %%
# Stack Graph Ploting For 'Vulnerability'
# Create graph figure model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stackplot(x, v, labels=['Vulnerability'], color=['brown'])

#lablel
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(0, 12)

ax.legend()

plt.grid(True)

plt.show()

# %% [markdown]
# **C. SCATTER GRAPH PLOTING**

# %%
# Scatter graph ploting
# Create graph Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.scatter(x, y, label='Housing', color='blue')
ax.scatter(x, z, label='Poverty', color='black')
ax.scatter(x, v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Scatter GraphFor Housing
# Create Graph Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.scatter(x, y, label='Housing', color='blue')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index', color='green', fontsize=12)

#sticks/Ticks label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Scatter Graph Ploting For Poverty
# Create Graph Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.scatter(x, z, label='Poverty', color='black')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#sticks/Ticks label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Scatter graph ploting for Vulnerability
# Create Graph Figure
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.scatter(x, v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index', color='green',
             fontsize=12)

#sticks/Ticks label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **D. STEM PLOTING**

# %%
# Stem ploting for all threee
# Creating graph figure mpdule
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stem(x, y, label='Housing', linefmt='C0--')
ax.stem(x, z, label='Poverty', linefmt='C1--')
ax.stem(x, v, label='Vulnerability', linefmt='C2--')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Stem ploting for Housing
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stem(x, y, label='Housing', linefmt='C0--')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Stem graph ploting for Poverty
# Creating Graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stem(x, z, label='Poverty', linefmt='C1-')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Stem ploting for Vulnerability
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stem(x, v, label='Vulnerability', linefmt='C5-')

# Label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **E. HIST/HISTOGRAM GRAPH PLOTING**

# %%
# Histogram graph ploting for the all three 'Housing', 'Poverty', 'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.hist(y, label='Housing', color='blue')
ax.hist(z, label='Poverty', color='black')
ax.hist(v, label='Vulnerability', color='red')

#label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 14)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-23-fa277fd9def2>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Histogram graph ploting For'Housing'
# Creating Graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.hist(y, label='Housing', color='blue')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 14)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-24-e24e97e36dd5>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Histogram graph ploting For 'Poverty'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.hist(z, label='Poverty', color='black')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 14)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-25-faa52c6749b4>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Histogram Graph ploting for'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.hist(v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index', color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 14)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-26-1ca6e47e556f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %% [markdown]
# **F. BAR PLOTING**

# %%
# Bar Ploting For Three 'Housing', 'Poverty', 'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.bar(x, y, label='Housing', color='blue')
ax.bar(x, z, label='Poverty', color='black')
ax.bar(x, v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Bar Ploting For 'Housing'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.bar(x, y, label='Housing', color='blue')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %%
# Bar ploting For 'Poverty'
# Creating graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.bar(x, z, label='Poverty', color='black')

#label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Bar Ploting for 'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.bar(x, v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticks(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **G. STAIR GRAPH PLOTING**

# %%
# Stair Graph Poting For All three
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stairs(y, label='Housing', color='blue')
ax.stairs(z, label='Poverty', color='black')
ax.stairs(v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-35-85fdde4878d3>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Stair Ploting For 'HOUSING'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stairs(y, label='Housing', color='blue')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-37-774f8d6e0846>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Stair Graph Ploting For 'Poverty'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stairs(z, label='Poverty', color='black')

# labels
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-40-ddcc351dc491>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Stair Ploting for 'Vulnerability'
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.stairs(v, label='Vulnerability', color='red')

#labels
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-42-216420411829>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %% [markdown]
# **H. FILL BETWEEN PLOTING**

# %%
# Fill between graph ploting for all three
# Creating Graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.fill_between(x, y, label='Housing', color='blue')
ax.fill_between(x, z, label='Poverty', color='black')
ax.fill_between(x, v, label='Vulnerability', color='red')

# label
ax.set_xlabel('District', color='green')
ax.set_ylabel('Values', color='green')
ax.set_title('Nepal Earthquake Severity Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-45-571018d51c9d>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Fill between graph ploting for 'Housing;
# Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.fill_between(x, y, label='Housing', color='blue')

#labels
ax.set_xlabel('District', color='green')
ax.set_ylabel('Housing', color='green')
ax.set_title('Nepal Earthquake Housing Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-47-f3a6f3378ff7>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Fill Between Graph Ploting For 'Poverty'
#Creating Graph Model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.fill_between(x, z, label='Poverty', color='green')

#labels
ax.set_xlabel('District', color='green')
ax.set_ylabel('Poverty', color='green')
ax.set_title('Nepal Earthquake Poverty Index',
             color='red', fontsize=20)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-53-1f2c22afab69>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %%
# Fill Between graph ploting for 'Vulnerability'
# Creating Graph model
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

ax.fill_between(x, v, label='Vulnerability', color='violet')

#labels
ax.set_xlabel('District', color='green')
ax.set_ylabel('Vulnerability', color='green')
ax.set_title('Nepal Earthquake Vulnerability Index',
             color='green', fontsize=12)

#Stick/Ticks Label
ax.set_xticklabels(x)
ax.set_ylim(1, 12)

ax.legend()

plt.grid(True)

plt.show()
# Out:
# <ipython-input-57-c84c2226c1d4>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)

# %% [markdown]
# **I. CREATE ONE (2X2) AXES**

# %%
# Create one 2x2 axes
#Creating Graph Model
fig, ax = plt.subplots(2, 2)
fig.set_size_inches(18, 10)

#For all Three
ax[0, 0].plot(x, y, 'o-', label='Housing', color='blue')
ax[0, 0].plot(x, z, 'o--', label='Poverty', color='black')
ax[0, 0].plot(x, v, 'o-', label='Vulnerability', color='red')

#labels
ax[0, 0].set_title('Nepal Earthquake Severity Index',
                    color='green', fontsize=12)
ax[0, 0].set_xlabel('District', color='green')
ax[0, 0].set_ylabel('Values', color='green')
#Sticks/Ticks Labels
ax[0, 0].set_xticks(x)
ax[0, 0].set_ylim(0, 11)

ax[0, 0].legend()

ax[0, 0].grid(True)

#For 'Housing'

ax[0, 1].plot(x, y, 'o-', label='Housing', color='blue')

#labels
ax[0, 1].set_title('Nepal Earthquake Housing Index',
                    color='green', fontsize=12)
ax[0, 1].set_xlabel('District', color='green')
ax[0, 1].set_ylabel('Housing', color='green')

#sticks/Ticks Lables
ax[0, 1].set_xticks(x)
ax[0, 1].set_ylim(0, 11)

ax[0, 1].legend()

ax[0, 1].grid(True)

# For 'Poverty'
ax[1, 0].plot(x, z, 'o--', label='Poverty', color='black')

#labels
ax[1, 0].set_title('Nepal Earthquake Poverty Index',
                    color='blue', fontsize=12)
ax[1, 0].set_xlabel('District', color='green')
ax[1, 0].set_ylabel('Poverty', color='green')

#sticks/Ticks Labels
ax[1, 0].set_xticks(x)
ax[1, 0].set_ylim(0, 11)

ax[1, 0].legend()

ax[1, 0].grid(True)

# For 'Vulnerability'
ax[1, 1].plot(x, v, 'o-', label='Vulnerability', color='red')

#labels
ax[1, 1].set_title('Nepal Earthquake Vulnerability Index',
                    color='blue', fontsize=12)
ax[1, 1].set_xlabel('District', color='green')
ax[1, 1].set_ylabel('Vulnerability', color='green')

#sticks/Ticks Labels
ax[1, 1].set_xticks(x)
ax[1, 1].set_ylim(0, 11)

ax[1, 1].legend()

ax[1, 1].grid(True)

plt.show()
